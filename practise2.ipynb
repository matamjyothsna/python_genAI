# %%
# B - 105 --> participants

# %%
firstname = "matam"
lastname = "pruthvi"
# Out:
# matam pruthvi

# %%
# EX-1 ---> Sample
full_name = firstname + " " + lastname 
print(full_name)
print(full_name.title())
print(full_name.upper())
print(full_name.lower())
# Out:
# matam pruthvi
# Matam Pruthvi
# MATAM PRUTHVI
# matam pruthvi

# %%
# EX-2 ---> Using f-string
fullname = f"{firstname} {lastname}"
print(fullname)
print(fullname.title())
print(fullname.upper())
print(fullname.lower())
# Out:
# matam pruthvi
# Matam Pruthvi
# MATAM PRUTHVI
# matam pruthvi

# %%
# general syntax of f-strings
# EX-1 ---> Sample
message = f"My Name is {fullname.title()}"
print(message)
# Out:
# My Name is Matam Pruthvi

# %%
# EX-1 ---> Sample
print("Details:Name:JyothsnaAge:27")
# Out:
# Details:Name:JyothsnaAge:27

# %%
# EX-2 ---> Using \n
print("Details:\nName:Jyothsna\nAge:27")
# Out:
# Details:
# Name:Jyothsna
# Age:27

# %%
# EX-3 ---> Using \t
print("Details:\tName:Jyothsna\tAge:27")
# Out:
# Details:	Name:Jyothsna	Age:27

# %%
# Eliminating Whitespaces ---> strip()
name1 = " Ammulu"
name2 = "Jyo "
name3 = "Bujji"
name4 = " Jyothsna "

# %%
# Ex-1 --> left stripping
print(name1)
print(name1.lstrip())
# Out:
#  Ammulu
# Ammulu

# %%
# Ex-2 --> right stripping
print(name2)
print(name2.rstrip())
# Out:
# Jyo
# Jyo

# %%
# Ex-3 --> Sample
print(name3)
print(name3.lstrip())
# Out:
# Bujji
# Bujji

# %%
# Ex-4 --> stripping
print(name4)
print(name4.lstrip())
# Out:
#  Jyothsna
# Jyothsna
