# %%
# 1) BASIC

# %%
print("Hello World")
print("My Name is Jyothsna")
# Out:
# Hello World
# My Name is Jyothsna

# %%
# 2) VARIABLES

# %%
Name = "Jyothsna"
age = 27
x = 50
print(Name)
print(age)
print(x)
# Out:
# Jyothsna
# 27
# 50

# %%
# OPERATORS

# %%
A = 20
B = 30
x = 25
y = 75
C = A + B
z = x + y
print(C)
print(z)
# Out:
# 50
# 100

# %%
# 3) DATA TYPES

# %%
# 3-1) Strings
full_name = "maTam jyoTHsna"
print(full_name)
# Out:
# maTam jyoTHsna

# %%
# 3-1-a) Methods
print(type(full_name))
print(full_name.title())
print(full_name.upper())
print(full_name.lower())
# Out:
# <class 'str'>
# Matam Jyothsna
# MATAM JYOTHSNA
# matam jyothsna
