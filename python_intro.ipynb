# %%
# INTRODUCTION OF PYTHON FUNDAMENTALS

# %%
# 1) VARIABLES

# %%
# Understanding the variable in Python :- (Position Holders) 
a = 2
b = 3
c = a + b
print(c)
# Out:
# 5

# %%
# 1-a) Rules for Declaring Variables in Python

# %%
# # Rule - 1 => No name spaces while declaring the varible name
first name = "Jyothsna"
print(first name)

# %%
firstname = "Jyothsna"
print(firstname)
# Out:
# Jyothsna

# %%
# Rule - 2 (IMP) => A variable name should not start with a number
1name = "Mahi"
print(1name)

# %%
name1 = "Mahi"
print(name1)
# Out:
# Mahi

# %%
# # Rule - 3 => A variable name should not contain any special characters (@, #, $, %, &)
name@ = "Sravya"
print(name@)

# %%
# 2) DATA TYPES
    # 1) Strings --> str
    # 2) Numbers -- Integers --> int and float 
    # 3) List
    # 4) Tuple
    # 5) Dictionary --> Dict

# %%
# Classification of Data Types :- Broadly Two Types
#     1) Mutable --> Which we can edit/alter ---- flexible in Nature
#     2) Immutable --> Which we cannot edit/alter ---- Fixed in Nature

# %%
# 2-1) INTRUDUCTION TO STRING DATA TYPE

# %%
# Defination     -->  A String is nothing but a sequence of characters written in quotes
# Classification --> It is classified as an immutable data type
# how do u declare string :-
#     a) Approach - 1 :- Using single quote
#     b) Approach - 2 :- Using double quote

# %%
Name = 'Jyothsna'     # Using single quote
name = "Jyo"          # Using double quote
print(Name)
print(name)
# Out:
# Jyothsna
# Jyo

# %%
# 2-1-a) Introduction to String Methods (Built-in Functions) :-

# %%
print(type(Name))
print(type(name))
# Out:
# <class 'str'>
# <class 'str'>

# %%
fullname = "pruthvi"
print(fullname)
# Out:
# pruthvi

# %%
# requirment --> how to correct format

# 1) first letter should be Capital
print(fullname.title())

# 2) Entire name should be Capital
print(fullname.upper())

# 3) Entire name should be Lower
print(fullname.lower())
# Out:
# Pruthvi
# PRUTHVI
# pruthvi
