# %%
# B - 105 --> participants

# %%
# 3) Create List
fruits = ["Apple", "Mango", "Orange", "Mango", "Watermelon", "Pineapple"]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Orange', 'Mango', 'Watermelon', 'Pineapple']

# %%
# 3-a) Indexing
print(fruits[2])
print(fruits[0:4])
print(fruits[-2: ])
print(fruits[-4: -2])
# Out:
# Orange
# ['Apple', 'Mango', 'Orange', 'Mango']
# ['Watermelon', 'Pineapple']
# ['Orange', 'Mango']

# %%
# 3-b) Methods

# %%
# 3-b-a) adding

# %%
# EX - 1
fruits.append("Papaya")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Orange', 'Mango', 'Watermelon', 'Pineapple', 'Papaya']

# %%
# EX - 2
fruits.insert(3, "Strawberry")
print(fruits)
# Out:
# ['Apple', 'Mango', 'Orange', 'Strawberry', 'Mango', 'Watermelon', 'Pineapple', 'Papaya']

# %%
# 3-b-b) modify

# %%
fruits[2] = "Pomegranate"
print(fruits)
# Out:
# ['Apple', 'Mango', 'Pomegranate', 'Strawberry', 'Mango', 'Watermelon', 'Pineapple', 'Papaya']

# %%
# 3-c-c) delete

# %%
# EX - 1
fruits.pop()
print(fruits)
# Out:
# ['Apple', 'Mango', 'Pomegranate', 'Strawberry', 'Mango', 'Watermelon', 'Pineapple']

# %%
# EX - 2
del fruits[4]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Pomegranate', 'Strawberry', 'Watermelon', 'Pineapple']
